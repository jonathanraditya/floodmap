# %%
#Initializing modules
import pandas as pd
import numpy as np
import os
import json
import copy
import math

# %%
#Function
def fileList(folderPath):
    '''
    Store file name inside specified folder in array
    
    Input : folder path relative to current document
    Output : List
    '''
    fileList=[]
    for files in os.listdir(folderPath):
        fileList.append(files)
    return fileList

def bmkgPrepDataCleaning(folderPath, currentFileOut):
    getFileLists=fileList(folderPath)
    
    listInit=[]
    
    #Write result(s) header to file
    with open(currentFileOut, 'w') as fileObject:
        #fileObject.write(json.dump(listInit, indent=5))
        json.dump(listInit, fileObject, indent=5)
        
    for i in range(len(getFileLists)):
        currentData=pd.read_excel(folderPath+getFileLists[i], header=None)
        currentStationName=currentData[2][1].replace(":", "").strip()
        
        #Forward check
        #Make sure that it's not a false stop
        #Initializing data length param (to avoid header & footer miscalculation)
        #Use < and > for conditionals; index start from 0
        headerBoundary=9
        footerBoundary=len(currentData[0])-7-1 #The -1 is for normalizing index, so its started from 0

        fwdDataStatus=False
        currentResultData=[[],[]]
        for j in range(len(currentData[0])):
            if j<headerBoundary or j>footerBoundary: #Continuing iteration on xlsx header and footer
                continue
            #Check if there is a data or not
            data=currentData[1][j]
            if not pd.isna(data):
                fwdDataStatus=True
            if fwdDataStatus:
                currentResultData[0].append(currentData[0][j]) #dDate
                currentResultData[1].append(data)
                
        #Calculating Statistics
        try:
            #Count results
            countResults=len(currentResultData[1])
            #CountNaN
            countNaN=len([x for x in currentResultData[1] if pd.isna(x)])
            #countNaN=len([x for x in currentResultData[1] if x != 8888])
            #Count 8888
            count8888=len([x for x in currentResultData[1] if x==8888])
            #Count 9999
            count9999=len([x for x in currentResultData[1] if x==9999])
            #Start Date
            startDate=currentResultData[0][0]
            #End Date
            endDate=currentResultData[0][len(currentResultData[0])-1]
            #Bad result
            badResult=countNaN+count8888+count9999
            #Percentage Bad Result
            percBad=badResult/countResults*100
        except IndexError:
            #Count results
            countResults=None
            #CountNaN
            countNaN=None
            #Count 8888
            count8888=None
            #Count 9999
            count9999=None
            #Start Date
            startDate=None
            #End Date
            endDate=None
            #Bad result
            badResult=None
            #Percentage Bad Result
            percBad=None
        
        #Write result(s) to file
        resultDict={"namastasiun":currentStationName,
                    "prep":{
                        "data":currentResultData,
                        "statistics":{
                            "totalentry":countResults,
                            "startdate":startDate,
                            "enddate":endDate,
                            "countNaN":countNaN,
                            "count8888":count8888,
                            "count9999":count9999,
                            "badresults":badResult,
                            "percbadres":percBad
                        }
                    }
                   }
        with open(currentFileOut, 'r+') as fileObject:
            data=json.load(fileObject)
            data.append(resultDict)
            fileObject.seek(0)
            json.dump(data,fileObject)
            #fileObject.write(json.dumps(resultDict))
        print("Completed {}/{}. Current : {}".format(i,len(getFileLists),currentStationName))
    
        
    print("Completed")

# %%
#Folder path & initiating folder contents
bmkgDataPath='./raw/'
docName=fileList(bmkgDataPath)

# %%
print(bmkgDataPath+docName[0])
currentData=pd.read_excel(bmkgDataPath+docName[0], header=None)
#print(currentData)
# Out:
# ./raw/Balai Besar Meteorologi, Klimatologi, dan Geofisika Wilayah I.xlsx

# %%
#Get and trim current station data regarding what file name is
print(currentData[2][1].replace(":", "").strip())
# Out:
# Balai Besar Meteorologi, Klimatologi, dan Geofisika Wilayah I

# %%
#Conditional check if NaN or not
print(pd.isna(currentData[0][1]))
currentData[1][4]
# Out:
# True
# 'Elevasi'

# %%
currentData[:50]
# Out:
#              0             1  \
# 0          NaN        ID WMO
# 1          NaN  Nama Stasiun
# 2          NaN       Lintang
# 3          NaN         Bujur
# 4          NaN       Elevasi
# 5          NaN           NaN
# 6          NaN           NaN
# 7          NaN           NaN
# 8      Tanggal            RR
# 9   01-01-1968           NaN
# 10  02-01-1968           NaN
# 11  03-01-1968           NaN
# 12  04-01-1968           NaN
# 13  05-01-1968           NaN
# 14  06-01-1968           NaN
# 15  07-01-1968           NaN
# 16  08-01-1968           NaN
# 17  09-01-1968           NaN
# 18  10-01-1968           NaN
# 19  11-01-1968           NaN
# 20  12-01-1968           NaN
# 21  13-01-1968           NaN
# 22  14-01-1968           NaN
# 23  15-01-1968           NaN
# 24  16-01-1968           NaN
# 25  17-01-1968           NaN
# 26  18-01-1968           NaN
# 27  19-01-1968           NaN
# 28  20-01-1968           NaN
# 29  21-01-1968           NaN
# 30  22-01-1968           NaN
# 31  23-01-1968           NaN
# 32  24-01-1968           NaN
# 33  25-01-1968           NaN
# 34  26-01-1968           NaN
# 35  27-01-1968           NaN
# 36  28-01-1968           NaN
# 37  29-01-1968           NaN
# 38  30-01-1968           NaN
# 39  31-01-1968           NaN
# 40  01-02-1968           NaN
# 41  02-02-1968           NaN
# 42  03-02-1968           NaN
# 43  04-02-1968           NaN
# 44  05-02-1968           NaN
# 45  06-02-1968           NaN
# 46  07-02-1968           NaN
# 47  08-02-1968           NaN
# 48  09-02-1968           NaN
# 49  10-02-1968           NaN
#
#                                                     2
# 0                                            :  96041
# 1   :  Balai Besar Meteorologi, Klimatologi, dan G...
# 2                                          :  3.53970
# 3                                         :  98.64000
# 4                                                :  0
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
#Forward check
#Make sure that it's not a false stop
#Initializing data length param (to avoid header & footer miscalculation)
#Use < and > for conditionals; index start from 0
headerBoundary=9
footerBoundary=len(currentData[0])-7-1 #The -1 is for normalizing index, so its started from 0

fwdDataStatus=False
resultData=[[],[]]
for i in range(len(currentData[0])):
    if i<headerBoundary or i>footerBoundary: #Continuing iteration on xlsx header and footer
        continue
    #Check if there is a data or not
    data=currentData[1][i]
    if not pd.isna(data):
        fwdDataStatus=True
    if fwdDataStatus:
        resultData[0].append(currentData[0][i]) #dDate
        resultData[1].append(data)
#print(i)
#print(resultData)

#Backward check
#Make sure that it's not a false stop

#Getting insight
#Count NaN, 8888, 9999, start date, total data from start date
#Get percentage for NaN, 8888, 9999

#print(resultData)

#Count results
countResults=len(resultData[1])
#print(countResults)

#CountNaN
countNaN=len([x for x in resultData[1] if pd.isna(x)])
#print(countNaN)

#Count 8888
count8888=len([x for x in resultData[1] if x==8888])

#Count 9999
count9999=len([x for x in resultData[1] if x==9999])

#Start Date
# Completed 190/191. Current : Stasiun Pemantau Atmosfer Global Puncak Vihara Klademak
# Completed

# %%
cleanedDataPath="prepCleanedDataJSON.json"
with open(cleanedDataPath, 'r') as cd:
    opened=cd.read()
    
loadDatas=json.loads(opened)
#print(loadDatas[0].keys())

for i in range(len(loadDatas)):
    namaStasiun=loadDatas[i]['namastasiun']
    totalEntry=loadDatas[i]['prep']['statistics']['totalentry']
    startDate=loadDatas[i]['prep']['statistics']['startdate']
    endDate=loadDatas[i]['prep']['statistics']['enddate']
    percBadRes=loadDatas[i]['prep']['statistics']['percbadres']
    percBadRes=(loadDatas[i]['prep']['statistics']['count8888'] + loadDatas[i]['prep']['statistics']['count9999']) / loadDatas[i]['prep']['statistics']['totalentry']*100
    try:
        print("{}% | {} - Count : {}, {} (=>) {}".format(round(percBadRes,1), namaStasiun,totalEntry,startDate,endDate))
    except TypeError:
        print("{}% | {} - Count : {}, {} (=>) {}".format(percBadRes, namaStasiun,totalEntry,startDate,endDate))
# Out:
# 4.5% | Balai Besar Meteorologi, Klimatologi, dan Geofisika Wilayah I - Count : 4567, 01-07-2007 (=>) 31-12-2019
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15256/2993577445.py in <module>
#      12     endDate=loadDatas[i]['prep']['statistics']['enddate']
#      13     percBadRes=loadDatas[i]['prep']['statistics']['percbadres']
# ---> 14     percBadRes=(loadDatas[i]['prep']['statistics']['count8888'] + loadDatas[i]['prep']['statistics']['count9999']) / loadDatas[i]['prep']['statistics']['totalentry']*100
#      15     try:
#      16         print("{}% | {} - Count : {}, {} (=>) {}".format(round(percBadRes,1), namaStasiun,totalEntry,startDate,endDate))
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
i=2
rn=0
ns=loadDatas[i]['namastasiun']
sanCheck=loadDatas[i]['prep']['data'][1][rn]
dtsanCheck=loadDatas[i]['prep']['data'][0][rn]
print(ns, dtsanCheck, sanCheck)
# Out:
# Halim Perdana Kusuma Jakarta 02-01-1980 8

# %%
copyData=copy.deepcopy(loadDatas)
sortedByPerc=sorted(copyData, key=lambda x : 0 if x['prep']['statistics']['percbadres'] is None else x['prep']['statistics']['percbadres'])

#print(sortedByPerc)

for i in range(len(loadDatas)):
    namaStasiun=sortedByPerc[i]['namastasiun']
    totalEntry=sortedByPerc[i]['prep']['statistics']['totalentry']
    startDate=sortedByPerc[i]['prep']['statistics']['startdate']
    endDate=sortedByPerc[i]['prep']['statistics']['enddate']
    percBadRes=sortedByPerc[i]['prep']['statistics']['percbadres']
    
    try:
        calculateYearofRecords=round((1-percBadRes/100)*totalEntry/365,1)
        print("{}% - {} | {} - Count : {}, {} (=>) {}".format(round(percBadRes,1), calculateYearofRecords, namaStasiun,totalEntry,startDate,endDate))
    except TypeError:
        percBadRes=None
        print("{}% - {} | {} - Count : {}, {} (=>) {}".format(percBadRes, "None", namaStasiun,totalEntry,startDate,endDate))
# Out:
# None% - None | Balai Besar Meteorologi, Klimatologi, dan Geofisika Wilayah IV - Count : None, None (=>) None
# None% - None | Stasiun Geofisika Alor - Count : None, None (=>) None
Count : 3652, 01-01-2010 (=>) 31-12-2019
# 51.5% - 3.1 | Stasiun Meteorologi Utarom - Count : 2349, 27-07-2013 (=>) 31-12-2019
# 51.8% - 12.4 | Stasiun Klimatologi Aceh Besar - Count : 9406, 01-04-1994 (=>) 31-12-2019
# 52.1% - 19.7 | Stasiun Meteorologi Seigun - Count : 14975, 01-01-1979 (=>) 31-12-2019
# 54.2% - 20.1 | Stasiun Meteorologi Mutiara Sis-Al Jufri - Count : 16071, 01-01-1976 (=>) 31-12-2019
# 60.2% - 2.5 | Stasiun Geofisika Palu - Count : 2261, 23-10-2013 (=>) 31-12-2019
# 60.3% - 4.0 | Stasiun Meteorologi Sultan Bantilan - Count : 3652, 01-01-2010 (=>) 31-12-2019
# 60.9% - 1.0 | Stasiun Klimatologi Kampar - Count : 944, 01-06-2017 (=>) 31-12-2019
# 62.1% - 0.4 | Stasiun Klimatologi Tanah Miring - Count : 364, 02-01-2019 (=>) 31-12-2019
# 63.8% - 11.9 | Stasiun Meteorologi Mopah - Count : 12053, 01-01-1987 (=>) 31-12-2019
# 64.4% - 3.6 | Stasiun Klimatologi Kupang - Count : 3652, 01-01-2010 (=>) 31-12-2019
# 64.5% - 6.0 | Stasiun Meteorologi Mararena - Count : 6209, 01-01-2003 (=>) 31-12-2019
# 68.5% - 12.9 | Stasiun Meteorologi Sudjarwo Tjondro Negoro - Count : 14975, 01-01-1979 (=>) 31-12-2019
# 68.8% - 1.9 | Stasiun Geofisika Kendari - Count : 2281, 03-10-2013 (=>) 31-12-2019
# 69.3% - 11.7 | Stasiun Meteorologi Wamena Jaya Wijaya - Count : 13875, 05-01-1982 (=>) 31-12-2019
# 73.4% - 10.6 | Halim Perdana Kusuma Jakarta - Count : 14609, 02-01-1980 (=>) 31-12-2019
# 73.4% - 11.6 | Stasiun Klimatologi Manokwari Selatan - Count : 15919, 01-06-1976 (=>) 31-12-2019
# 75.6% - 1.5 | Stasiun Geofisika Nabire - Count : 2265, 19-10-2013 (=>) 31-12-2019
# 81.9% - 1.0 | Stasiun Geofisika Banjarnegara - Count : 1949, 31-08-2014 (=>) 31-12-2019
# 86.2% - 0.8 | Stasiun Geofisika Karang Panjang - Count : 2010, 01-07-2014 (=>) 31-12-2019
# 89.4% - 0.4 | Stasiun Geofisika Angkasapura - Count : 1430, 01-02-2016 (=>) 31-12-2019
# 98.5% - 0.1 | Stasiun Pemantau Atmosfer Global Bukit Koto Tabang - Count : 2218, 05-12-2013 (=>) 31-12-2019
# 99.9% - 0.0 | Stasiun Geofisika Sorong - Count : 2283, 01-10-2013 (=>) 31-12-2019

# %%
# Rain Annua Maxima
for station_data in loadDatas:
    cdf = pd.DataFrame(station_data['prep']['data']).T
    cdf[1] = cdf[1].astype('float32')
    cdf[0] = cdf[0].astype('datetime64[ns]')

    # Remove data that flagged as missing or broken
    cdf = cdf.drop(cdf.loc[cdf[1] > 1000].index)

    # Make date column as index so Grouper would work (DatetimeIndex requirement)
    cdf = cdf.set_index(0, drop=True, append=False)

    annual_maxima = cdf.groupby(pd.Grouper(freq='Y')).max()
    annual_maxima = annual_maxima.drop(annual_maxima.loc[annual_maxima[1] != annual_maxima[1]].index)

    # Use data that have 3 or more years only
    if annual_maxima.shape[0] < 3:
        print(station_data['namastasiun'] + ' Not enough data')
        continue

    # annual_maxima['y'] = annual_maxima.index.year
    # annual_maxima = annual_maxima.set_index('y', drop=True, append=False)

    # Calculate estimated precipitation design for selected return period
    # !! USING WEIBULL (would be updated later after overall model is proven working) !!
    annual_maxima = annual_maxima.sort_values(by=1, ascending=False)
    annual_maxima[2] = np.arange(1, annual_maxima.shape[0] + 1)
    annual_maxima[3] = annual_maxima[2] / (annual_maxima.shape[0] + 1)
    # annual_maxima[4] = 1 / annual_maxima[3]

    # Create polynomial regression
    poly_trendline = np.poly1d(np.polyfit(annual_maxima[3],annual_maxima[1],2))
    
    # declimi
    print(f"{annual_maxima.shape[0]:<3} {station_data['namastasiun'][:30]:<35} {poly_trendline(1/2):.1f} {poly_trendline(1/5):.1f} {poly_trendline(1/10):.1f} {poly_trendline(1/25):.1f} {poly_trendline(1/50):.1f} {poly_trendline(1/100):.1f}")
# Out:
# 13  Balai Besar Meteorologi, Klima      100.5 136.5 153.3 164.6 168.5 170.5
# Balai Besar Meteorologi, Klimatologi, dan Geofisika Wilayah IV Not enough data
# 39  Halim Perdana Kusuma Jakarta        77.5 143.1 172.7 192.3 199.2 202.6
# 20  Stasiun Geofisika Aceh Selatan      89.3 102.3 105.6 107.3 107.8 108.1
# 20  Stasiun Geofisika Aceh Selatan      89.3 102.3 105.6 107.3 107.8 108.1
# 4   Pos Meteorologi Penggung            94.3 154.7 183.3 202.6 209.3 212.7
# 24  Pos Pengamatan Kahang-Kahang        99.6 130.3 138.2 142.4 143.7 144.3
# 6   Stasiun Geofisika Aceh Besar        110.1 189.0 226.1 251.0 259.7 264.1
# 20  Stasiun Geofisika Aceh Selatan      89.3 102.3 105.6 107.3 107.8 108.1
# Stasiun Geofisika Alor Not enough data
# Stasiun Geofisika Angkasapura Not enough data
# Stasiun Geofisika Balikpapan Not enough data
# 45  Stasiun Geofisika Bandung           75.4 100.1 111.5 119.1 121.8 123.2
# 6   Stasiun Geofisika Banjarnegara      96.3 135.9 150.7 160.0 163.2 164.8
# 39  Stasiun Geofisika Deli Serdang      104.8 151.6 172.4 186.1 190.8 193.3
# 10  Stasiun Geofisika Denpasar          100.9 143.2 162.9 176.0 180.6 183.0
# Stasiun Geofisika Gorontalo Not enough data
# 6   Stasiun Geofisika Gowa              84.2 181.1 217.6 240.5 248.3 252.2
# 6   Stasiun Geofisika Gunungsitoli      98.7 144.2 162.9 174.9 179.0 181.1
# Stasiun Geofisika Karang Panjang Not enough data
# 6   Stasiun Geofisika Kendari           35.3 120.6 161.3 188.8 198.4 203.3
# 10  Stasiun Geofisika Kepahiang         94.8 129.6 144.9 155.0 158.5 160.3
# Stasiun Geofisika Kupang Not enough data
# 10  Stasiun Geofisika Lampung Utar      112.3 142.8 153.5 160.0 162.2 163.3
# 10  Stasiun Geofisika Malang            90.8 116.0 128.7 137.4 140.5 142.1
# 3   Stasiun Geofisika Nabire            87.0 116.4 131.0 140.9 144.4 146.2
# 35  Stasiun Geofisika Nganjuk           128.3 172.0 188.3 198.6 202.0 203.8
# 24  Stasiun Geofisika Padang Panja      131.0 174.0 188.3 196.8 199.6 201.1
# 44  Stasiun Meteorologi Sultan Muh      95.3 137.5 155.6 167.5 171.6 173.7
# 38  Stasiun Meteorologi Sultan Muh      67.1 95.4 107.9 116.1 118.9 120.3
# 10  Stasiun Meteorologi Sultan Sya      127.9 164.9 183.2 195.6 199.9 202.2
# 35  Stasiun Meteorologi Sultan Tha      94.1 130.0 145.6 155.8 159.3 161.1
# 40  Stasiun Meteorologi Supadio         106.4 149.5 169.0 182.0 186.5 188.8
# 35  Stasiun Meteorologi Susilo          121.5 151.6 163.1 170.3 172.7 174.0
# 47  Stasiun Meteorologi Syamsudin       98.3 120.2 125.6 128.3 129.1 129.5
# 36  Stasiun Meteorologi Syukuran A      74.1 109.6 124.7 134.6 138.0 139.7
# 24  Stasiun Meteorologi Tanah Mera      141.3 218.0 247.6 266.3 272.7 275.9
# 33  Stasiun Meteorologi Tanjung Ha      105.8 145.5 162.4 173.5 177.4 179.3
# 38  Stasiun Meteorologi Tardamu         85.1 155.9 189.2 211.5 219.3 223.3
# 29  Stasiun Meteorologi Tarempa         142.9 196.3 216.3 228.8 233.1 235.2
# 37  Stasiun Meteorologi Tegal           100.0 148.7 171.3 186.4 191.7 194.4
# 42  Stasiun Meteorologi Temindung       91.3 155.4 186.9 208.2 215.7 219.5
# 42  Stasiun Meteorologi Tjilik Riw      133.4 166.9 181.5 191.0 194.3 195.9
# 40  Stasiun Meteorologi Torea           127.9 190.4 216.8 234.0 239.9 242.9
# 3   Stasiun Meteorologi Tuban           70.0 170.9 222.9 258.5 271.1 277.6
# 43  Stasiun Meteorologi Tunggul Wu      153.3 225.1 256.1 276.4 283.4 287.0
# 47  Stasiun Meteorologi Umbu Mehan      66.1 93.0 104.4 111.8 114.3 115.6
# 7   Stasiun Meteorologi Utarom          113.5 161.3 174.8 182.3 184.7 185.9
# 17  Stasiun Meteorologi Wamena Jay      52.2 81.6 94.5 103.0 105.9 107.4
# 30  Stasiun Meteorologi Yuvai Sema      81.8 137.0 163.1 180.6 186.8 189.9
# 49  Stasiun Meteorologi Zainuddin       94.4 161.4 193.1 214.3 221.8 225.6
# 4   Stasiun Pemantau Atmosfer Glob      2.4 40.5 61.5 76.1 81.3 84.0
# Stasiun Pemantau Atmosfer Global Lore Lindu Bariri Not enough data
# Stasiun Pemantau Atmosfer Global Puncak Vihara Klademak Not enough data

# %%
annual_maxima.shape[1]
# Out:
# 3

# %%
wb = 1 / 5
print(poly_trendline(wb))
# Out:
# 143.10827387759556

# %%
loadDatas[2]['prep']['statistics']
# Out:
# {'totalentry': 14609,
#  'startdate': '02-01-1980',
#  'enddate': '31-12-2019',
#  'countNaN': 10242,
#  'count8888': 480,
#  'count9999': 0,
#  'badresults': 10722,
#  'percbadres': 73.39311383393799}

# %%
# Get station metadata 

with open('./bmkgstationdata.json', 'r') as f:
    smd = json.load(f)

# %%
smd_df = pd.DataFrame(smd)

# %%
smd_df
# Out:
#     station_number                                       station_name  \
# 0            96013                       Stasiun Geofisika Aceh Besar
# 1            96585              Stasiun Meteorologi Maritim Pontianak
# 2            96807                     Stasiun Geofisika Banjarnegara
# 3            97692                       Stasiun Klimatologi Jayapura
# 4            97760                         Stasiun Meteorologi Utarom
# ..             ...                                                ...
# 186          97500  Stasiun Pemantau Atmosfer Global Puncak Vihara...
# 187          97247                             Stasiun Geofisika Alor
# 188          96043                       Stasiun Meteorologi Silangit
# 189          96747                       Halim Perdana Kusuma Jakarta
# 190          96004  Balai Besar Meteorologi, Klimatologi, dan Geof...
#
#     idrefregency type      region  latitude  longitude elevation      soil  \
# 0              6  mkg    Region I   5.49600   95.29600        32  52.00000
# 1            322  mkg   Region II  -0.03000  109.34000         4  52.00000
# 2            187  mkg   Region II  -7.33300  109.70690       608      None
# 3            460  mkg    Region V  -2.59231  140.16792        70      None
# 4            494  mkg    Region V  -3.67000  133.75000         5      None
# ..           ...  ...         ...       ...        ...       ...       ...
# 186          497  mkg    Region V  -0.98100  131.30100        10      None
# 187          293  mkg  Region III  -8.14450  124.59030         0      None
# 188           25  mkg    Region I   2.26136   98.99357      1420      None
# 189          157  mkg   Region II  -6.27036  106.88926        28      None
# 190          412  mkg   Region IV  -5.14283  119.45227        72      None
#
#     exposure land_use timezone wmo_id station_id
# 0         21       28   +07:00  96013        174
# 1         48       28   +07:00  96585        173
# 2       None     None   +07:00  96807        179
# 3       None     None   +09:00  97692        175
# 4       None     None   +09:00  97760        176
# ..       ...      ...      ...    ...        ...
# 186     None     None   +09:00  97500       7948
# 187     None     None   +08:00  97247      11185
# 188     None     None   +07:00  96043      11261
# 189     None     None   +07:00  96747      10890
# 190     None     None   +08:00  96004        171
#
# [191 rows x 14 columns]

# %%
smd_df.loc[smd_df['station_name'] == loadDatas[2]['namastasiun']]
# Out:
#     station_number                  station_name idrefregency type     region  \
# 189          96747  Halim Perdana Kusuma Jakarta          157  mkg  Region II
#
#      latitude  longitude elevation  soil exposure land_use timezone wmo_id  \
# 189  -6.27036  106.88926        28  None     None     None   +07:00  96747
#
#     station_id
# 189      10890

# %% [markdown]
# copyData2=copy.deepcopy(loadDatas)
# sortedByPerc=sorted(copyData2, key=lambda x : 0 if x['prep']['statistics']['percbadres'] is None else x['prep']['statistics']['percbadres']/x['prep']['statistics']['totalentry']*100/100/365)
#
# #print(sortedByPerc)
#
# for i in range(len(loadDatas)):
#     namaStasiun=sortedByPerc[i]['namastasiun']
#     totalEntry=sortedByPerc[i]['prep']['statistics']['totalentry']
#     startDate=sortedByPerc[i]['prep']['statistics']['startdate']
#     endDate=sortedByPerc[i]['prep']['statistics']['enddate']
#     percBadRes=sortedByPerc[i]['prep']['statistics']['percbadres']
#
#     try:
#         calculateYearofRecords=round((1-percBadRes/100)*totalEntry/365,1)
#         print("{}% - {} | {} - Count : {}, {} (=>) {}".format(round(percBadRes,1), calculateYearofRecords, namaStasiun,totalEntry,startDate,endDate))
#     except TypeError:
#         percBadRes=None
#         print("{}% - {} | {} - Count : {}, {} (=>) {}".format(percBadRes, "None", namaStasiun,totalEntry,startDate,endDate))
